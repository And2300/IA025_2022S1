# %% [markdown]
# <a href="https://colab.research.google.com/github/And2300/IA025_2022S1/blob/main/Aula8_Exerc%C3%ADcio_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = 'Andersson Romero'
print(f'Meu nome é {nome}')
# Out:
# Meu nome é Andersson Romero

# %% [markdown]
# #  Exercício: Modelo de Linguagem com auto-atenção

# %% [markdown]
# Este exercício é similar ao da Aula 7, mas iremos agora treinar uma rede neural *com auto-atenção* para prever a próxima palavra de um texto, data as palavras anteriores como entrada.
#
# Na camada de auto-atenção, não se esqueça de implementar:
# - Embeddings de posição
# - Projeções lineares (WQ, WK, WV, WO)
# - Conexões residuais
# - Camada de feed forward (2-layer MLP)
#
#
#
# O dataset usado neste exercício (BrWaC) possui um tamanho razoável e você vai precisar rodar seus experimentos com GPU.
#
# Alguns conselhos úteis:
# - **ATENÇÃO:** o dataset é bem grande. Não dê comando de imprimí-lo.
# - Durante a depuração, faça seu dataset ficar bem pequeno, para que a depuração seja mais rápida e não precise de GPU. Somente ligue a GPU quando o seu laço de treinamento já está funcionando
# - Não deixe para fazer esse exercício na véspera. Ele é trabalhoso.

# %%
# iremos utilizar a biblioteca dos transformers para ter acesso ao tokenizador do BERT.
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 8.2 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 49.9 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 53.5 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.5 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.7.0 pyyaml-6.0 tokenizers-0.12.1 transformers-4.19.2

# %% [markdown]
# ## Importação dos pacotes

# %%
import collections
import itertools
import functools
import math
import random

import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import DataLoader
from tqdm import tqdm_notebook

# %%
# Check which GPU we are using
# !nvidia-smi
# Out:
# Wed May 25 22:44:53 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
if torch.cuda.is_available(): 
   dev = "cuda:0"
else: 
   dev = "cpu"
device = torch.device(dev)
print('Using {}'.format(device))
# Out:
# Using cuda:0

# %% [markdown]
# ## Implementação do MyDataset

# %%
from typing import List


def tokenize(text: str, tokenizer):
    return tokenizer(text, return_tensors=None, add_special_tokens=False).input_ids


class MyDataset():
    def __init__(self, texts: List[str], tokenizer, context_size: int):
        self.examples = []
        for text in tqdm_notebook(texts):
            token_ids = tokenize(text=text, tokenizer=tokenizer)
            if len(token_ids) < context_size + 1:
                continue
            # Compute n-grams:
            for i in range(len(token_ids) - context_size):
                input_ids = token_ids[i:i + context_size]
                target_id = token_ids[i + context_size]
                self.examples.append((input_ids, target_id)) 

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, idx):
        input_ids, target_id = self.examples[idx]
        return torch.LongTensor(input_ids), target_id

# %% [markdown]
# ## Testando se a implementação do MyDataset está correta

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained("neuralmind/bert-base-portuguese-cased")

dummy_texts = ['Eu gosto de correr', 'Ela gosta muito de comer pizza']

dummy_dataset = MyDataset(texts=dummy_texts, tokenizer=tokenizer, context_size=3)
dummy_loader = DataLoader(dummy_dataset, batch_size=6, shuffle=False)
assert len(dummy_dataset) == 5
print('passou no assert de tamanho do dataset')

first_batch_input, first_batch_target = next(iter(dummy_loader))

correct_first_batch_input = torch.LongTensor(
    [[ 3396, 10303,   125],
     [ 1660,  5971,   785],
     [ 5971,   785,   125],
     [  785,   125,  1847],
     [  125,  1847, 13779]])

correct_first_batch_target = torch.LongTensor([13239,   125,  1847, 13779, 15616])

assert torch.equal(first_batch_input, correct_first_batch_input)
print('Passou no assert de input')
assert torch.equal(first_batch_target, correct_first_batch_target)
print('Passou no assert de target')
# Out:
# Downloading:   0%|          | 0.00/205k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/43.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/647 [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # This is added back by InteractiveShellApp.init_path()
#   0%|          | 0/2 [00:00<?, ?it/s]
# passou no assert de tamanho do dataset
# Passou no assert de input
# Passou no assert de target

# %% [markdown]
# # Carregamento do dataset

# %% [markdown]
# Iremos usar uma pequena amostra do dataset [BrWaC](https://www.inf.ufrgs.br/pln/wiki/index.php?title=BrWaC) para treinar e avaliar nosso modelo de linguagem.

# %%
# !wget -nc https://storage.googleapis.com/unicamp-dl/ia025a_2022s1/aula7/sample_brwac.txt
# Out:
# --2022-05-25 22:45:00--  https://storage.googleapis.com/unicamp-dl/ia025a_2022s1/aula7/sample_brwac.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.195.128, 173.194.202.128, 74.125.199.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.195.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 123983611 (118M) [text/plain]
# Saving to: ‘sample_brwac.txt’
#
# sample_brwac.txt    100%[===================>] 118.24M   190MB/s    in 0.6s
#
# 2022-05-25 22:45:01 (190 MB/s) - ‘sample_brwac.txt’ saved [123983611/123983611]

# %%
# Load datasets
context_size = 9

valid_examples = 100
test_examples = 100
texts = open('sample_brwac.txt').readlines()

print('Truncating for debugging purposes.')
texts = texts[:500]  

training_texts = texts[:-(valid_examples + test_examples)]
valid_texts = texts[-(valid_examples + test_examples):-test_examples]
test_texts = texts[-test_examples:]

training_dataset = MyDataset(texts=training_texts, tokenizer=tokenizer, context_size=context_size)
valid_dataset = MyDataset(texts=valid_texts, tokenizer=tokenizer, context_size=context_size)
test_dataset = MyDataset(texts=test_texts, tokenizer=tokenizer, context_size=context_size)
# Out:
# Truncating for debugging purposes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # This is added back by InteractiveShellApp.init_path()
#   0%|          | 0/300 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
print(f'training examples: {len(training_dataset)}')
print(f'valid examples: {len(valid_dataset)}')
print(f'test examples: {len(test_dataset)}')
# Out:
# training examples: 406905
# valid examples: 135562
# test examples: 136690

# %%
from collections import OrderedDict

class LanguageModel(torch.nn.Module):

    def __init__(self, vocab_size, context_size, embedding_dim):
        """
        Implements the Self-attention, decoder-only."

        Args:
            vocab_size (int): Size of the input vocabulary.
            context_size (int): Size of the sequence to consider as context for prediction.
            embedding_dim (int): Dimension of the embedding layer for each word in the context.
        """
        # Escreva seu código aqui.
        super(LanguageModel, self).__init__()
        self.vocab_size = vocab_size
        self.context_size = context_size
        self.embedding_dim = embedding_dim

        # Embedding of the words
        self.embeddings_C = nn.Embedding(vocab_size, embedding_dim)

        # Embedding of the words positions
        self.embeddings_P = nn.Embedding(context_size, embedding_dim) 

        # linear projections
        self.W_q = nn.Linear(embedding_dim, embedding_dim, bias=False)
        self.W_k = nn.Linear(embedding_dim, embedding_dim, bias=False)
        self.W_v = nn.Linear(embedding_dim, embedding_dim, bias=False)
        self.W_0 = nn.Linear(embedding_dim, embedding_dim, bias=False)

        # Linear layer
        hidden_size = 2*embedding_dim
        self.linear_layers = nn.Sequential(OrderedDict([
            ('dense1', nn.Linear(embedding_dim, hidden_size)),
            ('relu1',  nn.ReLU()),
            ('dense2', nn.Linear(hidden_size, vocab_size, bias = False))]))

        # Softmax
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, inputs):
        """
        Args:
            inputs is a LongTensor of shape (batch_size, context_size)
            
        Returns:
            logits of shape (batch_size, vocab_size)
        """
        # Escreva seu código aqui.
        batch_size = inputs.shape[0]
        pos = torch.arange(0, self.context_size).unsqueeze(0).repeat(batch_size,1).to(inputs.device)

        # Arguments of the model #
        ## B: batch_size
        ## L: context_size
        ## D: embedding_dim
        ## V: vocab_size

        # inputs shape: (B, L)
        # pos shape: (B, L)
        embeds = self.embeddings_C(inputs) # embeds shape: (B, L, D)
        embeds_pos = self.embeddings_P(pos) # embeds pos: (B, L, D)

        X = embeds + embeds_pos # X shape: (B, L, D)
        
        # Q = X[-1] * Wq
        X_1 = X[:,-1,:].unsqueeze(1) # X[:,-1,:] -> shape: (B, D)
        Q = self.W_q(X_1) # Q shape: (B, 1, D)
        # K = X * Wk
        K = self.W_k(X)     # K shape: (B, L, D)
        # V = X * Wv
        V = self.W_v(X)     # V shape: (B, L, D)
        
        # s = Q*K^T
        # normalized scores: s = s/sqrt(D)
        scores = torch.matmul(Q,torch.transpose(K,1,2))/math.sqrt(self.embedding_dim) # scores shape: (B, 1, L)
        probs = self.softmax(scores) # probs shape: (B, 1, L)
        
        E = torch.matmul(probs, V) # E shape: (B, 1, D)
        # E = E*W0
        
        E = self.W_0(E)
        logits = self.linear_layers(E.view(batch_size,-1)) # logits shape: (B, Vocab_size)
        return logits

# %% [markdown]
# ## Teste o modelo com um exemplo

# %%
model = LanguageModel(
    vocab_size=tokenizer.vocab_size,
    context_size=context_size,
    embedding_dim=64,
).to(device)

sample_train, _ = next(iter(DataLoader(training_dataset)))
sample_train_gpu = sample_train.to(device)
model(sample_train_gpu).shape
# Out:
# torch.Size([1, 29794])

# %%
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'Number of model parameters: {num_params}')
# Out:
# Number of model parameters: 5745728

# %% [markdown]
# ## Assert da Perplexidade

# %%
random.seed(123)
np.random.seed(123)
torch.manual_seed(123)


def perplexity(logits, target):
    """
    Computes the perplexity.

    Args:
        logits: a FloatTensor of shape (batch_size, vocab_size)
        target: a LongTensor of shape (batch_size,)

    Returns:
        A float corresponding to the perplexity
    """
    loss = nn.functional.cross_entropy(logits, target, reduction='mean')
    return torch.exp(loss)


n_examples = 1000

sample_train, target_token_ids = next(iter(DataLoader(training_dataset, batch_size=n_examples)))
sample_train_gpu = sample_train.to(device)
target_token_ids = target_token_ids.to(device)
logits = model(sample_train_gpu)

my_perplexity = perplexity(logits=logits, target=target_token_ids)

print(f'my perplexity:              {int(my_perplexity)}')
print(f'correct initial perplexity: {tokenizer.vocab_size}')

assert math.isclose(my_perplexity, tokenizer.vocab_size, abs_tol=7000)
print('Passou o no assert da perplexidade')
# Out:
# my perplexity:              29838
# correct initial perplexity: 29794
# Passou o no assert da perplexidade

# %% [markdown]
# ## Laço de Treinamento e Validação

# %%
max_examples = 100_000_000
eval_every_steps = 10000
lr = 3e-4


model = LanguageModel(
    vocab_size=tokenizer.vocab_size,
    context_size=context_size,
    embedding_dim=128,
).to(device)

train_loader = DataLoader(training_dataset, batch_size=64, shuffle=True, drop_last=True)
validation_loader = DataLoader(valid_dataset, batch_size=64)

optimizer = torch.optim.Adam(model.parameters(), lr=lr)


def train_step(input, target):
    model.train()
    model.zero_grad()

    logits = model(input.to(device))
    loss = nn.functional.cross_entropy(logits, target.to(device))
    loss.backward()
    optimizer.step()

    return loss.item()


def validation_step(input, target):
    model.eval()
    logits = model(input)
    loss = nn.functional.cross_entropy(logits, target)
    return loss.item()


train_losses = []
n_examples = 0
step = 0
while n_examples < max_examples:
    for input, target in train_loader:
        loss = train_step(input.to(device), target.to(device)) 
        train_losses.append(loss)
        
        if step % eval_every_steps == 0:
            train_ppl = np.exp(np.average(train_losses))

            with torch.no_grad():
                valid_ppl = np.exp(np.average([
                    validation_step(input.to(device), target.to(device))
                    for input, target in validation_loader]))

            print(f'{step} steps; {n_examples} examples so far; train ppl: {train_ppl:.2f}, valid ppl: {valid_ppl:.2f}')
            train_losses = []

        n_examples += len(input)  # Increment of batch size
        step += 1
        if n_examples >= max_examples:
            break
# Out:
# 0 steps; 0 examples so far; train ppl: 29889.19, valid ppl: 29710.98
# 10000 steps; 640000 examples so far; train ppl: 976.24, valid ppl: 1326.50
# 20000 steps; 1280000 examples so far; train ppl: 321.62, valid ppl: 2518.63
# 30000 steps; 1920000 examples so far; train ppl: 170.06, valid ppl: 4416.22
# 40000 steps; 2560000 examples so far; train ppl: 124.87, valid ppl: 7825.21
# 50000 steps; 3200000 examples so far; train ppl: 102.45, valid ppl: 9874.01
# 60000 steps; 3840000 examples so far; train ppl: 86.87, valid ppl: 18951.39
# 70000 steps; 4480000 examples so far; train ppl: 79.34, valid ppl: 24940.42
# 80000 steps; 5120000 examples so far; train ppl: 68.91, valid ppl: 37976.39
# 90000 steps; 5760000 examples so far; train ppl: 64.81, valid ppl: 37492.03
# 100000 steps; 6400000 examples so far; train ppl: 58.81, valid ppl: 48957.37
# 110000 steps; 7040000 examples so far; train ppl: 55.14, valid ppl: 79142.58
# 120000 steps; 7680000 examples so far; train ppl: 51.90, valid ppl: 82073.46
# 130000 steps; 8320000 examples so far; train ppl: 48.16, valid ppl: 130902.76
# 140000 steps; 8960000 examples so far; train ppl: 46.70, valid ppl: 206012.33
# 150000 steps; 9600000 examples so far; train ppl: 42.92, valid ppl: 221522.57
# 160000 steps; 10240000 examples so far; train ppl: 41.60, valid ppl: 277949.87
# 170000 steps; 10880000 examples so far; train ppl: 39.25, valid ppl: 343241.82
# 180000 steps; 11520000 examples so far; train ppl: 37.59, valid ppl: 491281.58
# 190000 steps; 12160000 examples so far; train ppl: 36.28, valid ppl: 483217.38
# 200000 steps; 12800000 examples so far; train ppl: 34.16, valid ppl: 711408.12
# 210000 steps; 13440000 examples so far; train ppl: 33.57, valid ppl: 1092799.48
# 220000 steps; 14080000 examples so far; train ppl: 31.50, valid ppl: 1440398.82
# 230000 steps; 14720000 examples so far; train ppl: 30.71, valid ppl: 2304909.81
# 240000 steps; 15360000 examples so far; train ppl: 29.45, valid ppl: 2223282.53
# 250000 steps; 16000000 examples so far; train ppl: 28.41, valid ppl: 4350020.07
# 260000 steps; 16640000 examples so far; train ppl: 27.75, valid ppl: 3463459.18
# 270000 steps; 17280000 examples so far; train ppl: 26.31, valid ppl: 5648338.96
# 280000 steps; 17920000 examples so far; train ppl: 26.12, valid ppl: 12264964.74
# 290000 steps; 18560000 examples so far; train ppl: 24.75, valid ppl: 10665281.16
# 300000 steps; 19200000 examples so far; train ppl: 24.36, valid ppl: 14813231.67
# 310000 steps; 19840000 examples so far; train ppl: 23.50, valid ppl: 20034733.90
# 320000 steps; 20480000 examples so far; train ppl: 22.76, valid ppl: 30099549.12
# 330000 steps; 21120000 examples so far; train ppl: 22.52, valid ppl: 22812957.52
# 340000 steps; 21760000 examples so far; train ppl: 21.45, valid ppl: 34346028.29
# 350000 steps; 22400000 examples so far; train ppl: 21.36, valid ppl: 37803358.59
# 360000 steps; 23040000 examples so far; train ppl: 20.37, valid ppl: 52306230.58
# 370000 steps; 23680000 examples so far; train ppl: 20.15, valid ppl: 73935397.09
# 380000 steps; 24320000 examples so far; train ppl: 19.58, valid ppl: 73417929.18
# 390000 steps; 24960000 examples so far; train ppl: 19.11, valid ppl: 130081885.35
# 400000 steps; 25600000 examples so far; train ppl: 18.91, valid ppl: 83417822.98
# 410000 steps; 26240000 examples so far; train ppl: 18.15, valid ppl: 252807275.23
# 420000 steps; 26880000 examples so far; train ppl: 18.10, valid ppl: 305008643.27
# 430000 steps; 27520000 examples so far; train ppl: 17.44, valid ppl: 261479790.76
# 440000 steps; 28160000 examples so far; train ppl: 17.18, valid ppl: 396160392.69
# 450000 steps; 28800000 examples so far; train ppl: 16.87, valid ppl: 306180650.17
# 460000 steps; 29440000 examples so far; train ppl: 16.45, valid ppl: 655404150.75
# 470000 steps; 30080000 examples so far; train ppl: 16.34, valid ppl: 507105105.98
# 480000 steps; 30720000 examples so far; train ppl: 15.71, valid ppl: 1051769459.46
# 490000 steps; 31360000 examples so far; train ppl: 15.73, valid ppl: 1186661178.79
# 500000 steps; 32000000 examples so far; train ppl: 15.20, valid ppl: 1135824965.63
# 510000 steps; 32640000 examples so far; train ppl: 15.05, valid ppl: 1770129744.76
# 520000 steps; 33280000 examples so far; train ppl: 14.83, valid ppl: 1907122250.57
# 530000 steps; 33920000 examples so far; train ppl: 14.41, valid ppl: 2795467971.20
# 540000 steps; 34560000 examples so far; train ppl: 14.45, valid ppl: 2180456414.32
# 550000 steps; 35200000 examples so far; train ppl: 13.90, valid ppl: 4883877332.96
# 560000 steps; 35840000 examples so far; train ppl: 13.90, valid ppl: 6743398959.08
# 570000 steps; 36480000 examples so far; train ppl: 13.53, valid ppl: 4626016950.39
# 580000 steps; 37120000 examples so far; train ppl: 13.35, valid ppl: 7766764938.48
# 590000 steps; 37760000 examples so far; train ppl: 13.22, valid ppl: 6482309946.46
# 600000 steps; 38400000 examples so far; train ppl: 12.91, valid ppl: 16607974107.93
# 610000 steps; 39040000 examples so far; train ppl: 12.91, valid ppl: 12325838453.43
# 620000 steps; 39680000 examples so far; train ppl: 12.46, valid ppl: 21133263670.40
# 630000 steps; 40320000 examples so far; train ppl: 12.52, valid ppl: 30201891698.65
# 640000 steps; 40960000 examples so far; train ppl: 12.14, valid ppl: 35378623111.54
# 650000 steps; 41600000 examples so far; train ppl: 12.07, valid ppl: 28300115576.90
# 660000 steps; 42240000 examples so far; train ppl: 11.91, valid ppl: 35162936164.33
# 670000 steps; 42880000 examples so far; train ppl: 11.67, valid ppl: 53096819788.44
# 680000 steps; 43520000 examples so far; train ppl: 11.69, valid ppl: 49601937102.33
# 690000 steps; 44160000 examples so far; train ppl: 11.27, valid ppl: 71771201882.73
# 700000 steps; 44800000 examples so far; train ppl: 11.37, valid ppl: 120438458278.24
# 710000 steps; 45440000 examples so far; train ppl: 11.07, valid ppl: 87826419694.51
# 720000 steps; 46080000 examples so far; train ppl: 10.98, valid ppl: 146309626607.44
# 730000 steps; 46720000 examples so far; train ppl: 10.93, valid ppl: 107797855835.28
# 740000 steps; 47360000 examples so far; train ppl: 10.67, valid ppl: 214006083579.90
# 750000 steps; 48000000 examples so far; train ppl: 10.70, valid ppl: 169930684371.70
# 760000 steps; 48640000 examples so far; train ppl: 10.38, valid ppl: 218473769805.46
# 770000 steps; 49280000 examples so far; train ppl: 10.42, valid ppl: 379519744486.44
# 780000 steps; 49920000 examples so far; train ppl: 10.20, valid ppl: 445010925125.80
# 790000 steps; 50560000 examples so far; train ppl: 10.09, valid ppl: 593154990781.15
# 800000 steps; 51200000 examples so far; train ppl: 10.06, valid ppl: 631660623369.54
# 810000 steps; 51840000 examples so far; train ppl: 9.82, valid ppl: 805529754129.49
# 820000 steps; 52480000 examples so far; train ppl: 9.94, valid ppl: 794184860421.10
# 830000 steps; 53120000 examples so far; train ppl: 9.59, valid ppl: 1373432475056.69
# 840000 steps; 53760000 examples so far; train ppl: 9.64, valid ppl: 1535275704372.63
# 850000 steps; 54400000 examples so far; train ppl: 9.48, valid ppl: 1541586541268.05
# 860000 steps; 55040000 examples so far; train ppl: 9.40, valid ppl: 2729901186304.65
# 870000 steps; 55680000 examples so far; train ppl: 9.35, valid ppl: 2166171846129.20
# 880000 steps; 56320000 examples so far; train ppl: 9.15, valid ppl: 3083086135477.86
# 890000 steps; 56960000 examples so far; train ppl: 9.26, valid ppl: 2755530444257.56
# 900000 steps; 57600000 examples so far; train ppl: 8.96, valid ppl: 3179039928077.27
# 910000 steps; 58240000 examples so far; train ppl: 8.97, valid ppl: 6717929790872.84
# 920000 steps; 58880000 examples so far; train ppl: 8.86, valid ppl: 5778682324702.08
# 930000 steps; 59520000 examples so far; train ppl: 8.76, valid ppl: 6766139871994.07
# 940000 steps; 60160000 examples so far; train ppl: 8.75, valid ppl: 6986572264221.92
# 950000 steps; 60800000 examples so far; train ppl: 8.57, valid ppl: 12470669543138.26
# 960000 steps; 61440000 examples so far; train ppl: 8.64, valid ppl: 8234681395625.81
# 970000 steps; 62080000 examples so far; train ppl: 8.39, valid ppl: 10005308963513.36
# 980000 steps; 62720000 examples so far; train ppl: 8.44, valid ppl: 22660019118332.53
# 990000 steps; 63360000 examples so far; train ppl: 8.35, valid ppl: 17813726551793.25
# 1000000 steps; 64000000 examples so far; train ppl: 8.27, valid ppl: 18220378177152.57
# 1010000 steps; 64640000 examples so far; train ppl: 8.23, valid ppl: 20526720480039.51
# 1020000 steps; 65280000 examples so far; train ppl: 8.09, valid ppl: 31712503664818.75
# 1030000 steps; 65920000 examples so far; train ppl: 8.15, valid ppl: 47330410283749.82
# 1040000 steps; 66560000 examples so far; train ppl: 7.90, valid ppl: 40999362720087.74
# 1050000 steps; 67200000 examples so far; train ppl: 7.97, valid ppl: 76114122978652.91
# 1060000 steps; 67840000 examples so far; train ppl: 7.87, valid ppl: 65618272350553.76
# 1070000 steps; 68480000 examples so far; train ppl: 7.79, valid ppl: 103335941157376.05
# 1080000 steps; 69120000 examples so far; train ppl: 7.84, valid ppl: 60799828274648.16
# 1090000 steps; 69760000 examples so far; train ppl: 7.65, valid ppl: 87202192601776.06
# 1100000 steps; 70400000 examples so far; train ppl: 7.72, valid ppl: 130424371416460.22
# 1110000 steps; 71040000 examples so far; train ppl: 7.53, valid ppl: 110106340343872.09
# 1120000 steps; 71680000 examples so far; train ppl: 7.54, valid ppl: 183978950274987.56
# 1130000 steps; 72320000 examples so far; train ppl: 7.49, valid ppl: 119886409934661.14
# 1140000 steps; 72960000 examples so far; train ppl: 7.41, valid ppl: 151078127617648.25
# 1150000 steps; 73600000 examples so far; train ppl: 7.41, valid ppl: 188813744290379.97
# 1160000 steps; 74240000 examples so far; train ppl: 7.27, valid ppl: 310696941183857.50
# 1170000 steps; 74880000 examples so far; train ppl: 7.34, valid ppl: 327291232780420.50
# 1180000 steps; 75520000 examples so far; train ppl: 7.19, valid ppl: 236018595382161.72
# 1190000 steps; 76160000 examples so far; train ppl: 7.20, valid ppl: 411820507527295.56
# 1200000 steps; 76800000 examples so far; train ppl: 7.14, valid ppl: 348873705393303.94
# 1210000 steps; 77440000 examples so far; train ppl: 7.07, valid ppl: 459697502898331.31
# 1220000 steps; 78080000 examples so far; train ppl: 7.12, valid ppl: 523734783542192.75
# 1230000 steps; 78720000 examples so far; train ppl: 6.94, valid ppl: 741854241625858.25
# 1240000 steps; 79360000 examples so far; train ppl: 7.02, valid ppl: 1066237236703246.38
# 1250000 steps; 80000000 examples so far; train ppl: 6.86, valid ppl: 1105287708501203.00
# 1260000 steps; 80640000 examples so far; train ppl: 6.89, valid ppl: 979041276641079.50
# 1270000 steps; 81280000 examples so far; train ppl: 6.83, valid ppl: 1406715036354774.75
# 1280000 steps; 81920000 examples so far; train ppl: 6.78, valid ppl: 2126060106085984.00
# 1290000 steps; 82560000 examples so far; train ppl: 6.81, valid ppl: 1186775643992953.25
# 1300000 steps; 83200000 examples so far; train ppl: 6.67, valid ppl: 1340255493916021.75
# 1310000 steps; 83840000 examples so far; train ppl: 6.72, valid ppl: 2899174091751707.50
# 1320000 steps; 84480000 examples so far; train ppl: 6.62, valid ppl: 2808034862958156.00
# 1330000 steps; 85120000 examples so far; train ppl: 6.59, valid ppl: 2136938687291101.25
# 1340000 steps; 85760000 examples so far; train ppl: 6.58, valid ppl: 3513196667915704.00
# 1350000 steps; 86400000 examples so far; train ppl: 6.50, valid ppl: 5027020568853283.00
# 1360000 steps; 87040000 examples so far; train ppl: 6.56, valid ppl: 1742198968150467.50
# 1370000 steps; 87680000 examples so far; train ppl: 6.42, valid ppl: 3218585631436721.50
# 1380000 steps; 88320000 examples so far; train ppl: 6.48, valid ppl: 5956004343836431.00
# 1390000 steps; 88960000 examples so far; train ppl: 6.35, valid ppl: 8013886513142059.00
# 1400000 steps; 89600000 examples so far; train ppl: 6.34, valid ppl: 7009657350609450.00
# 1410000 steps; 90240000 examples so far; train ppl: 6.35, valid ppl: 7219505173880959.00
# 1420000 steps; 90880000 examples so far; train ppl: 6.27, valid ppl: 10735069754452428.00
# 1430000 steps; 91520000 examples so far; train ppl: 6.32, valid ppl: 12705728448306582.00
# 1440000 steps; 92160000 examples so far; train ppl: 6.18, valid ppl: 12976048367353874.00
# 1450000 steps; 92800000 examples so far; train ppl: 6.26, valid ppl: 21938586197486804.00
# 1460000 steps; 93440000 examples so far; train ppl: 6.16, valid ppl: 21225917402973012.00
# 1470000 steps; 94080000 examples so far; train ppl: 6.14, valid ppl: 16915188966535328.00
# 1480000 steps; 94720000 examples so far; train ppl: 6.17, valid ppl: 13804884846699702.00
# 1490000 steps; 95360000 examples so far; train ppl: 6.07, valid ppl: 28044406256210824.00
# 1500000 steps; 96000000 examples so far; train ppl: 6.12, valid ppl: 16415200193979906.00
# 1510000 steps; 96640000 examples so far; train ppl: 6.00, valid ppl: 40334138610654320.00
# 1520000 steps; 97280000 examples so far; train ppl: 6.05, valid ppl: 27282375248188816.00
# 1530000 steps; 97920000 examples so far; train ppl: 5.95, valid ppl: 42517795215781880.00
# 1540000 steps; 98560000 examples so far; train ppl: 5.95, valid ppl: 34052472062751460.00
# 1550000 steps; 99200000 examples so far; train ppl: 5.95, valid ppl: 28224204495385752.00
# 1560000 steps; 99840000 examples so far; train ppl: 5.86, valid ppl: 78833887903691296.00

# %% [markdown]
# ## Avaliação final no dataset de teste
#
#
# Bonus: o modelo com menor perplexidade no dataset de testes ganhará 0.5 ponto na nota final.

# %%
test_loader = DataLoader(test_dataset, batch_size=64)

with torch.no_grad():
    test_ppl = np.exp(np.average([
        validation_step(input.to(device), target.to(device))
        for input, target in test_loader
    ]))

print(f'test perplexity: {test_ppl}')
# Out:
# test perplexity: 1.482376680645335e+17

# %% [markdown]
# ## Teste seu modelo com uma sentença
#
# Escolha uma sentença gerada pelo modelo que ache interessante.

# %%
prompt = 'Eu gosto de comer pizza pois me faz'
max_output_tokens = 20
model.eval()

for _ in range(max_output_tokens):
    input_ids = tokenize(text=prompt, tokenizer=tokenizer)
    input_ids_truncated = input_ids[-context_size:]  # Usamos apenas os últimos <context_size> tokens como entrada para o modelo.
    logits = model(torch.LongTensor([input_ids_truncated]).to(device))
    # Ao usarmos o argmax, a saída do modelo em cada passo é o token de maior probabilidade.
    # Isso se chama decodificação gulosa (greedy decoding).
    predicted_id = torch.argmax(logits).item()
    input_ids += [predicted_id]  # Concatenamos a entrada com o token escolhido nesse passo.
    prompt = tokenizer.decode(input_ids)
    print(prompt)
# Out:
# Eu gosto de comer pizza pois me faz muito
# Eu gosto de comer pizza pois me faz muito distante
# Eu gosto de comer pizza pois me faz muito distante,
# Eu gosto de comer pizza pois me faz muito distante, que
# Eu gosto de comer pizza pois me faz muito distante, que a
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e Cultura
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e Cultura à
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e Cultura à medida
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e Cultura à medida que
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e Cultura à medida que sint
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e Cultura à medida que sintamos
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e Cultura à medida que sintamos sozinho
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e Cultura à medida que sintamos sozinhos
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e Cultura à medida que sintamos sozinhos.
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e Cultura à medida que sintamos sozinhos. O
# Eu gosto de comer pizza pois me faz muito distante, que a quantidade de Minas e Cultura à medida que sintamos sozinhos. O desaparecimento
